# %%
import numpy as np
import pandas as pd

# %%
df_raw = pd.read_csv('property_listings.csv')

# %%
#Converts the columns to the best possible data types
#Permet de reconnaître les colonnes string, integer ou encore booléennes etc...
df_raw = df_raw.convert_dtypes()

# %%
#Prints the 5 first and last rows
df_raw
# Out:
#             zpid    price     homeStatus       homeType  datePosted  \
# 0       32107262   750000  Recently Sold   Multi Family  2024-03-19
# 1       20503342     3995  Recently Sold      Apartment  2024-09-24
# 2       20183958   820000  Recently Sold  Single Family  2024-10-27
# 3       32332472   550000  Recently Sold  Single Family  2024-07-09
# 4      352427429   703478  Recently Sold  Single Family  2024-06-19
# ...          ...      ...            ...            ...         ...
# 18773   16735997   994000       For Sale          Condo  2024-11-24
# 18774   16823913  1390000       For Sale  Single Family  2024-11-24
# 18775   17176040   795000       For Sale  Single Family  2024-11-24
# 18776   15177502   950000       For Sale  Single Family  2024-11-24
# 18777   82362288   615000       For Sale      Townhouse  2024-11-24
#
#                      streetAddress           city state  zipcode  \
# 0                     7417 87th Rd        Jamaica    NY    11421
# 1         1300 Midvale Ave APT 510    Los Angeles    CA    90024
# 2                   8300 Capps Ave     Northridge    CA    91324
# 3                   433 Hamden Ave  Staten Island    NY    10306
# 4                  504 Edwin St #8      Nashville    TN    37207
# ...                            ...            ...   ...      ...
# 18773           17616 Corte Potosi      San Diego    CA    92128
# 18774            10941 Waterton Rd      San Diego    CA    92131
# 18775           3954 Via Del Bardo     San Ysidro    CA    92173
# 18776               22 Chicago Way  San Francisco    CA    94112
# 18777  1015 NE 123rd Street UNIT B        Seattle    WA    98125
#
#                      county  ...  rentZestimate  bathrooms bedrooms  \
# 0             Queens County  ...           2930        2.0     <NA>
# 1        Los Angeles County  ...           3867        2.0        2
# 2        Los Angeles County  ...           4540        2.0        3
# 3           Richmond County  ...           2668        1.0        2
# 4           Davidson County  ...           3599        4.0        4
# ...                     ...  ...            ...        ...      ...
# 18773      San Diego County  ...           3056        2.0        2
# 18774      San Diego County  ...           5248        4.0        5
# 18775      San Diego County  ...           3744        3.0        4
# 18776  San Francisco County  ...           3578        2.0        2
# 18777           King County  ...           2991        2.0        3
#
#        pageViewCount  favoriteCount  propertyTaxRate  timeOnZillow  \
# 0                 20              0             0.86       9 hours
# 1                187              5             1.16       9 hours
# 2                 21              0             1.16       9 hours
# 3                 96              0             0.89       9 hours
# 4                  7              0             0.57       9 hours
# ...              ...            ...              ...           ...
# 18773             45              1             1.17       5 hours
# 18774            440             35             1.17       7 hours
# 18775             35              2             1.17      21 hours
# 18776            596             33             1.18         1 day
# 18777            216             19             0.77      22 hours
#
#          dateSold                                                url  \
# 0      2024-11-24  https://www.zillow.com/homedetails/7417-87th-R...
# 1      2024-11-24  https://www.zillow.com/homedetails/1300-Midval...
# 2      2024-11-24  https://www.zillow.com/homedetails/8300-Capps-...
# 3      2024-11-24  https://www.zillow.com/homedetails/433-Hamden-...
# 4      2024-11-24  https://www.zillow.com/homedetails/504-Edwin-S...
# ...           ...                                                ...
# 18773        <NA>  https://www.zillow.com/homedetails/17616-Corte...
# 18774        <NA>  https://www.zillow.com/homedetails/10941-Water...
# 18775        <NA>  https://www.zillow.com/homedetails/3954-Via-De...
# 18776        <NA>  https://www.zillow.com/homedetails/22-Chicago-...
# 18777        <NA>  https://www.zillow.com/homedetails/1015-NE-123...
#
#                           lastUpdated
# 0      2024-11-25 09:04:11.007468 UTC
# 1      2024-11-25 09:04:11.007468 UTC
# 2      2024-11-25 09:04:11.007468 UTC
# 3      2024-11-25 09:04:11.007468 UTC
# 4      2024-11-25 09:04:11.007468 UTC
# ...                               ...
# 18773  2024-11-25 05:33:30.941175 UTC
# 18774  2024-11-25 05:33:30.941175 UTC
# 18775  2024-11-25 05:33:30.941175 UTC
# 18776  2024-11-25 05:33:30.941175 UTC
# 18777  2024-11-25 05:33:30.941175 UTC
#
# [18778 rows x 23 columns]

# %%
df_raw.shape
# Out:
# (18778, 23)

# %%
#Names of the different columns
df_raw.columns
# Out:
# Index(['zpid', 'price', 'homeStatus', 'homeType', 'datePosted',
#        'streetAddress', 'city', 'state', 'zipcode', 'county', 'yearBuilt',
#        'livingArea', 'livingAreaUnits', 'rentZestimate', 'bathrooms',
#        'bedrooms', 'pageViewCount', 'favoriteCount', 'propertyTaxRate',
#        'timeOnZillow', 'dateSold', 'url', 'lastUpdated'],
#       dtype='object')

# %%
len(df_raw.columns)
# Out:
# 23

# %%
#Displays the components of the 5 first rows, with the columns and the rows transposed
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

display_all(df_raw.head().T)
# Out:
#                                                                  0  \
# zpid                                                      32107262
# price                                                       750000
# homeStatus                                           Recently Sold
# homeType                                              Multi Family
# datePosted                                              2024-03-19
# streetAddress                                         7417 87th Rd
# city                                                       Jamaica
# state                                                           NY
# zipcode                                                      11421
# county                                               Queens County
# yearBuilt                                                     <NA>
# livingArea                                                    <NA>
# livingAreaUnits                                               <NA>
# rentZestimate                                                 2930
# bathrooms                                                      2.0
# bedrooms                                                      <NA>
# pageViewCount                                                   20
# favoriteCount                                                    0
# propertyTaxRate                                               0.86
# timeOnZillow                                               9 hours
# dateSold                                                2024-11-24
# url              https://www.zillow.com/homedetails/7417-87th-R...
# lastUpdated                         2024-11-25 09:04:11.007468 UTC
#
#                                                                  1  \
# zpid                                                      20503342
# price                                                         3995
# homeStatus                                           Recently Sold
# homeType                                                 Apartment
# datePosted                                              2024-09-24
# streetAddress                             1300 Midvale Ave APT 510
# city                                                   Los Angeles
# state                                                           CA
# zipcode                                                      90024
# county                                          Los Angeles County
# yearBuilt                                                     1968
# livingArea                                                    1156
# livingAreaUnits                                               sqft
# rentZestimate                                                 3867
# bathrooms                                                      2.0
# bedrooms                                                         2
# pageViewCount                                                  187
# favoriteCount                                                    5
# propertyTaxRate                                               1.16
# timeOnZillow                                               9 hours
# dateSold                                                2024-11-24
# url              https://www.zillow.com/homedetails/1300-Midval...
# lastUpdated                         2024-11-25 09:04:11.007468 UTC
#
#                                                                  2  \
# zpid                                                      20183958
# price                                                       820000
# homeStatus                                           Recently Sold
# homeType                                             Single Family
# datePosted                                              2024-10-27
# streetAddress                                       8300 Capps Ave
# city                                                    Northridge
# state                                                           CA
# zipcode                                                      91324
# county                                          Los Angeles County
# yearBuilt                                                     1957
# livingArea                                                    1678
# livingAreaUnits                                               sqft
# rentZestimate                                                 4540
# bathrooms                                                      2.0
# bedrooms                                                         3
# pageViewCount                                                   21
# favoriteCount                                                    0
# propertyTaxRate                                               1.16
# timeOnZillow                                               9 hours
# dateSold                                                2024-11-24
# url              https://www.zillow.com/homedetails/8300-Capps-...
# lastUpdated                         2024-11-25 09:04:11.007468 UTC
#
#                                                                  3  \
# zpid                                                      32332472
# price                                                       550000
# homeStatus                                           Recently Sold
# homeType                                             Single Family
# datePosted                                              2024-07-09
# streetAddress                                       433 Hamden Ave
# city                                                 Staten Island
# state                                                           NY
# zipcode                                                      10306
# county                                             Richmond County
# yearBuilt                                                     1925
# livingArea                                                    1200
# livingAreaUnits                                               sqft
# rentZestimate                                                 2668
# bathrooms                                                      1.0
# bedrooms                                                         2
# pageViewCount                                                   96
# favoriteCount                                                    0
# propertyTaxRate                                               0.89
# timeOnZillow                                               9 hours
# dateSold                                                2024-11-24
# url              https://www.zillow.com/homedetails/433-Hamden-...
# lastUpdated                         2024-11-25 09:04:11.007468 UTC
#
#                                                                  4
# zpid                                                     352427429
# price                                                       703478
# homeStatus                                           Recently Sold
# homeType                                             Single Family
# datePosted                                              2024-06-19
# streetAddress                                      504 Edwin St #8
# city                                                     Nashville
# state                                                           TN
# zipcode                                                      37207
# county                                             Davidson County
# yearBuilt                                                     1949
# livingArea                                                    1808
# livingAreaUnits                                               sqft
# rentZestimate                                                 3599
# bathrooms                                                      4.0
# bedrooms                                                         4
# pageViewCount                                                    7
# favoriteCount                                                    0
# propertyTaxRate                                               0.57
# timeOnZillow                                               9 hours
# dateSold                                                2024-11-24
# url              https://www.zillow.com/homedetails/504-Edwin-S...
# lastUpdated                         2024-11-25 09:04:11.007468 UTC
